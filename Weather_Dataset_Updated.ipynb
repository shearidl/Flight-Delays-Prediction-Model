# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Initial global weather dataset cleaning, creation of new U.S. csv

# %%
# reading in the original file
# source: https://www.ncei.noaa.gov/data/global-summary-of-the-day/archive/

#df = pd.read_csv("combined-files.csv", skiprows=[3389713])
#df
# Out:
#              STATION        DATE     LATITUDE    LONGITUDE ELEVATION  \
# 0        01001099999  2024-01-01   70.9333333   -8.6666667       9.0
# 1        01001099999  2024-01-02   70.9333333   -8.6666667       9.0
# 2        01001099999  2024-01-03   70.9333333   -8.6666667       9.0
# 3        01001099999  2024-01-04   70.9333333   -8.6666667       9.0
# 4        01001099999  2024-01-05   70.9333333   -8.6666667       9.0
# ...              ...         ...          ...          ...       ...
# 3389707  86934099999  2024-06-24  -25.5166666  -48.8166666      60.5
# 3389708  86934099999  2024-06-25  -25.5166666  -48.8166666      60.5
# 3389709  86934099999  2024-06-26  -25.5166666  -48.8166666      60.5
# 3389710  86934099999  2024-06-27  -25.5166666  -48.8166666      60.5
# 3389711  86934099999  2024-06-28  -25.5166666  -48.8166666      60.5
#
#                            NAME    TEMP TEMP_ATTRIBUTES    DEWP  \
# 0        JAN MAYEN NOR NAVY, NO    26.6              24    20.5
# 1        JAN MAYEN NOR NAVY, NO    33.3              24    30.9
# 2        JAN MAYEN NOR NAVY, NO    29.7              24    27.2
# 3        JAN MAYEN NOR NAVY, NO    19.5              24    14.8
# 4        JAN MAYEN NOR NAVY, NO    20.6              24    16.5
# ...                         ...     ...             ...     ...
# 3389707            MORRETES, BR    71.6              24    62.3
# 3389708            MORRETES, BR    60.4              20  9999.9
# 3389709            MORRETES, BR    64.5              22  9999.9
# 3389710            MORRETES, BR    63.8              22  9999.9
# 3389711            MORRETES, BR    66.3              24  9999.9
#
#         DEWP_ATTRIBUTES  ...  MXSPD   GUST     MAX MAX_ATTRIBUTES     MIN  \
# 0                    24  ...   21.0   27.8    32.9                   17.4
# 1                    24  ...   15.3   20.6    34.5                   31.1
# 2                    24  ...   22.5   30.1    34.3                   25.3
# 3                    24  ...   25.6   32.1    28.8                   14.7
# 4                    24  ...   22.0   31.9    26.6              *    16.0
# ...                 ...  ...    ...    ...     ...            ...     ...
# 3389707              24  ...    5.2   13.6    83.5                   65.3
# 3389708               0  ...    0.6   10.9    65.7                   58.5
# 3389709               0  ...  999.9  999.9    76.8                   57.2
# 3389710               0  ...    2.3   13.6    68.7                   61.5
# 3389711               0  ...    1.0  999.9    84.9                   55.2
#
#         MIN_ATTRIBUTES   PRCP PRCP_ATTRIBUTES   SNDP  FRSHTT
# 0                        0.01               G  999.9  000000
# 1                       99.99                  999.9  111000
# 2                        0.00               G  999.9  000000
# 3                        0.00               G  999.9  001000
# 4                        0.06               G  999.9  001000
# ...                ...    ...             ...    ...     ...
# 3389707                  0.00               I  999.9  000000
# 3389708              *   0.00               I  999.9  000000
# 3389709                  0.00               I  999.9  000000
# 3389710                  0.00               I  999.9  000000
# 3389711                  0.00               I  999.9  000000
#
# [3389712 rows x 28 columns]

# %%
# creating a new column with countries

#df["COUNTRY"] = df["NAME"].str[-2:]

# getting just U.S. data
#df = df[df["COUNTRY"] == "US"]

# %%
#df
# Out:
#              STATION        DATE  LATITUDE   LONGITUDE ELEVATION  \
# 2055254  69015093121  2024-01-01    34.294  -116.14722     610.5
# 2055255  69015093121  2024-01-02    34.294  -116.14722     610.5
# 2055256  69015093121  2024-01-03    34.294  -116.14722     610.5
# 2055257  69015093121  2024-01-04    34.294  -116.14722     610.5
# 2055258  69015093121  2024-01-05    34.294  -116.14722     610.5
# ...              ...         ...       ...         ...       ...
# 3163848  78551011624  2024-12-27  17.69965   -64.81249      14.0
# 3163849  78551011624  2024-12-28  17.69965   -64.81249      14.0
# 3163850  78551011624  2024-12-29  17.69965   -64.81249      14.0
# 3163851  78551011624  2024-12-30  17.69965   -64.81249      14.0
# 3163852  78551011624  2024-12-31  17.69965   -64.81249      14.0
#
#                                     NAME    TEMP TEMP_ATTRIBUTES    DEWP  \
# 2055254       TWENTYNINE PALMS MC, CA US    46.5              24    36.3
# 2055255       TWENTYNINE PALMS MC, CA US    49.3              24    33.7
# 2055256       TWENTYNINE PALMS MC, CA US    47.2              24    35.1
# 2055257       TWENTYNINE PALMS MC, CA US    48.8              24    30.1
# 2055258       TWENTYNINE PALMS MC, CA US    47.7              24    28.6
# ...                                  ...     ...             ...     ...
# 3163848  HENRY E. ROHLSEN AIRPORT, VI US    79.3              24    73.4
# 3163849  HENRY E. ROHLSEN AIRPORT, VI US    77.3              23    72.2
# 3163850  HENRY E. ROHLSEN AIRPORT, VI US    77.1              12    65.6
# 3163851  HENRY E. ROHLSEN AIRPORT, VI US    76.3              19    65.2
# 3163852  HENRY E. ROHLSEN AIRPORT, VI US    75.8              20    66.8
#
#         DEWP_ATTRIBUTES  ...   GUST     MAX MAX_ATTRIBUTES     MIN  \
# 2055254              24  ...  999.9    59.0                   36.0
# 2055255              24  ...  999.9    64.0                   36.0
# 2055256              24  ...   25.1    64.0                   37.9
# 2055257              24  ...   33.0    57.9                   39.0
# 2055258              24  ...   15.9    60.1                   37.9
# ...                 ...  ...    ...     ...            ...     ...
# 3163848              24  ...  999.9    87.1                   73.9
# 3163849              23  ...   19.0    86.0                   73.0
# 3163850              12  ...   19.0    82.9                   73.0
# 3163851              19  ...   14.0    84.0                   69.1
# 3163852              20  ...   19.0    84.0                   70.0
#
#         MIN_ATTRIBUTES   PRCP PRCP_ATTRIBUTES   SNDP  FRSHTT COUNTRY
# 2055254                  0.00               I  999.9  000000      US
# 2055255                  0.00               I  999.9  000000      US
# 2055256                  0.02               B  999.9  010000      US
# 2055257                  0.00               I  999.9  000000      US
# 2055258                  0.00               I  999.9  000000      US
# ...                ...    ...             ...    ...     ...     ...
# 3163848                  0.00               G  999.9  010000      US
# 3163849                  0.00               G  999.9  010000      US
# 3163850                  0.06               G  999.9  000000      US
# 3163851                  0.00               G  999.9  010000      US
# 3163852                  0.08               G  999.9  010000      US
#
# [768591 rows x 29 columns]

# %%
# converting latitude and longitude to numeric values

# df["LAT_NUM"] = pd.to_numeric(df["LATITUDE"], errors="coerce")
# df["LON_NUM"] = pd.to_numeric(df["LONGITUDE"], errors="coerce")
# Out:
# /var/folders/h6/bld4mdpj7rl15xnhcry_95l00000gn/T/ipykernel_16177/820085865.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["LAT_NUM"] = pd.to_numeric(df["LATITUDE"], errors="coerce")
# /var/folders/h6/bld4mdpj7rl15xnhcry_95l00000gn/T/ipykernel_16177/820085865.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["LON_NUM"] = pd.to_numeric(df["LONGITUDE"], errors="coerce")

# %%
# reseting index

#df = df.reset_index(drop=True)
#df
# Out:
#             STATION        DATE  LATITUDE   LONGITUDE ELEVATION  \
# 0       69015093121  2024-01-01    34.294  -116.14722     610.5
# 1       69015093121  2024-01-02    34.294  -116.14722     610.5
# 2       69015093121  2024-01-03    34.294  -116.14722     610.5
# 3       69015093121  2024-01-04    34.294  -116.14722     610.5
# 4       69015093121  2024-01-05    34.294  -116.14722     610.5
# ...             ...         ...       ...         ...       ...
# 768586  78551011624  2024-12-27  17.69965   -64.81249      14.0
# 768587  78551011624  2024-12-28  17.69965   -64.81249      14.0
# 768588  78551011624  2024-12-29  17.69965   -64.81249      14.0
# 768589  78551011624  2024-12-30  17.69965   -64.81249      14.0
# 768590  78551011624  2024-12-31  17.69965   -64.81249      14.0
#
#                                    NAME    TEMP TEMP_ATTRIBUTES    DEWP  \
# 0            TWENTYNINE PALMS MC, CA US    46.5              24    36.3
# 1            TWENTYNINE PALMS MC, CA US    49.3              24    33.7
# 2            TWENTYNINE PALMS MC, CA US    47.2              24    35.1
# 3            TWENTYNINE PALMS MC, CA US    48.8              24    30.1
# 4            TWENTYNINE PALMS MC, CA US    47.7              24    28.6
# ...                                 ...     ...             ...     ...
# 768586  HENRY E. ROHLSEN AIRPORT, VI US    79.3              24    73.4
# 768587  HENRY E. ROHLSEN AIRPORT, VI US    77.3              23    72.2
# 768588  HENRY E. ROHLSEN AIRPORT, VI US    77.1              12    65.6
# 768589  HENRY E. ROHLSEN AIRPORT, VI US    76.3              19    65.2
# 768590  HENRY E. ROHLSEN AIRPORT, VI US    75.8              20    66.8
#
#        DEWP_ATTRIBUTES  ... MAX_ATTRIBUTES     MIN MIN_ATTRIBUTES   PRCP  \
# 0                   24  ...                   36.0                  0.00
# 1                   24  ...                   36.0                  0.00
# 2                   24  ...                   37.9                  0.02
# 3                   24  ...                   39.0                  0.00
# 4                   24  ...                   37.9                  0.00
# ...                ...  ...            ...     ...            ...    ...
# 768586              24  ...                   73.9                  0.00
# 768587              23  ...                   73.0                  0.00
# 768588              12  ...                   73.0                  0.06
# 768589              19  ...                   69.1                  0.00
# 768590              20  ...                   70.0                  0.08
#
#        PRCP_ATTRIBUTES   SNDP  FRSHTT COUNTRY   LAT_NUM    LON_NUM
# 0                    I  999.9  000000      US  34.29400 -116.14722
# 1                    I  999.9  000000      US  34.29400 -116.14722
# 2                    B  999.9  010000      US  34.29400 -116.14722
# 3                    I  999.9  000000      US  34.29400 -116.14722
# 4                    I  999.9  000000      US  34.29400 -116.14722
# ...                ...    ...     ...     ...       ...        ...
# 768586               G  999.9  010000      US  17.69965  -64.81249
# 768587               G  999.9  010000      US  17.69965  -64.81249
# 768588               G  999.9  000000      US  17.69965  -64.81249
# 768589               G  999.9  010000      US  17.69965  -64.81249
# 768590               G  999.9  010000      US  17.69965  -64.81249
#
# [768591 rows x 31 columns]

# %%
# creating a new weather CSV with just US data
# df.to_csv("large_weather_US.csv", index=False)

# %% [markdown]
# # Reading in new U.S. weather dataset

# %%
df = pd.read_csv("large_weather_US.csv")
df
# Out:
#             STATION        DATE  LATITUDE  LONGITUDE  ELEVATION  \
# 0       69015093121  2024-01-01  34.29400 -116.14722      610.5
# 1       69015093121  2024-01-02  34.29400 -116.14722      610.5
# 2       69015093121  2024-01-03  34.29400 -116.14722      610.5
# 3       69015093121  2024-01-04  34.29400 -116.14722      610.5
# 4       69015093121  2024-01-05  34.29400 -116.14722      610.5
# ...             ...         ...       ...        ...        ...
# 768586  78551011624  2024-12-27  17.69965  -64.81249       14.0
# 768587  78551011624  2024-12-28  17.69965  -64.81249       14.0
# 768588  78551011624  2024-12-29  17.69965  -64.81249       14.0
# 768589  78551011624  2024-12-30  17.69965  -64.81249       14.0
# 768590  78551011624  2024-12-31  17.69965  -64.81249       14.0
#
#                                    NAME  TEMP  TEMP_ATTRIBUTES  DEWP  \
# 0            TWENTYNINE PALMS MC, CA US  46.5               24  36.3
# 1            TWENTYNINE PALMS MC, CA US  49.3               24  33.7
# 2            TWENTYNINE PALMS MC, CA US  47.2               24  35.1
# 3            TWENTYNINE PALMS MC, CA US  48.8               24  30.1
# 4            TWENTYNINE PALMS MC, CA US  47.7               24  28.6
# ...                                 ...   ...              ...   ...
# 768586  HENRY E. ROHLSEN AIRPORT, VI US  79.3               24  73.4
# 768587  HENRY E. ROHLSEN AIRPORT, VI US  77.3               23  72.2
# 768588  HENRY E. ROHLSEN AIRPORT, VI US  77.1               12  65.6
# 768589  HENRY E. ROHLSEN AIRPORT, VI US  76.3               19  65.2
# 768590  HENRY E. ROHLSEN AIRPORT, VI US  75.8               20  66.8
#
#         DEWP_ATTRIBUTES  ...  MAX_ATTRIBUTES   MIN  MIN_ATTRIBUTES  PRCP  \
# 0                    24  ...                  36.0                  0.00
# 1                    24  ...                  36.0                  0.00
# 2                    24  ...                  37.9                  0.02
# 3                    24  ...                  39.0                  0.00
# 4                    24  ...                  37.9                  0.00
# ...                 ...  ...             ...   ...             ...   ...
# 768586               24  ...                  73.9                  0.00
# 768587               23  ...                  73.0                  0.00
# 768588               12  ...                  73.0                  0.06
# 768589               19  ...                  69.1                  0.00
# 768590               20  ...                  70.0                  0.08
#
#         PRCP_ATTRIBUTES   SNDP  FRSHTT  COUNTRY   LAT_NUM    LON_NUM
# 0                     I  999.9       0       US  34.29400 -116.14722
# 1                     I  999.9       0       US  34.29400 -116.14722
# 2                     B  999.9   10000       US  34.29400 -116.14722
# 3                     I  999.9       0       US  34.29400 -116.14722
# 4                     I  999.9       0       US  34.29400 -116.14722
# ...                 ...    ...     ...      ...       ...        ...
# 768586                G  999.9   10000       US  17.69965  -64.81249
# 768587                G  999.9   10000       US  17.69965  -64.81249
# 768588                G  999.9       0       US  17.69965  -64.81249
# 768589                G  999.9   10000       US  17.69965  -64.81249
# 768590                G  999.9   10000       US  17.69965  -64.81249
#
# [768591 rows x 31 columns]

# %% [markdown]
# # Visualization of weather data for one day

# %%
import plotly.express as px
import pandas as pd

df_visualize = df[df["DATE"] == "2024-01-01"]

fig = px.scatter_mapbox(df_visualize, lat='LATITUDE', lon='LONGITUDE',
                          hover_name="NAME", zoom=3)
fig.update_layout(title='US Weather Data on Jan. 1, 2024', mapbox_style='open-street-map')
fig.update_layout(autosize=False, width=1000, height=600,margin=dict(l=0, r=0, t=50, b=0))

fig.show()

# %% [markdown]
# # Cleaning U.S. weather dataset & EDA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768591 entries, 0 to 768590
# Data columns (total 31 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   STATION           768591 non-null  int64
#  1   DATE              768591 non-null  object
#  2   LATITUDE          768591 non-null  float64
#  3   LONGITUDE         768591 non-null  float64
#  4   ELEVATION         768591 non-null  float64
#  5   NAME              768591 non-null  object
#  6   TEMP              768591 non-null  float64
#  7   TEMP_ATTRIBUTES   768591 non-null  int64
#  8   DEWP              768591 non-null  float64
#  9   DEWP_ATTRIBUTES   768591 non-null  int64
#  10  SLP               768591 non-null  float64
#  11  SLP_ATTRIBUTES    768591 non-null  int64
#  12  STP               768591 non-null  float64
#  13  STP_ATTRIBUTES    768591 non-null  int64
#  14  VISIB             768591 non-null  float64
#  15  VISIB_ATTRIBUTES  768591 non-null  int64
#  16  WDSP              768591 non-null  float64
#  17  WDSP_ATTRIBUTES   768591 non-null  int64
#  18  MXSPD             768591 non-null  float64
#  19  GUST              768591 non-null  float64
#  20  MAX               768591 non-null  float64
#  21  MAX_ATTRIBUTES    768591 non-null  object
#  22  MIN               768591 non-null  float64
#  23  MIN_ATTRIBUTES    768591 non-null  object
#  24  PRCP              768591 non-null  float64
#  25  PRCP_ATTRIBUTES   768591 non-null  object
#  26  SNDP              768591 non-null  float64
#  27  FRSHTT            768591 non-null  int64
#  28  COUNTRY           768591 non-null  object
#  29  LAT_NUM           768591 non-null  float64
#  30  LON_NUM           768591 non-null  float64
# dtypes: float64(17), int64(8), object(6)
# memory usage: 181.8+ MB

# %%
# dropping irrelevant columns from df

df.drop(columns=["TEMP_ATTRIBUTES", "DEWP_ATTRIBUTES", "SLP_ATTRIBUTES", "STP_ATTRIBUTES", 
                 "VISIB_ATTRIBUTES", "WDSP_ATTRIBUTES", "MAX_ATTRIBUTES", "MIN_ATTRIBUTES",
                 "PRCP_ATTRIBUTES", "COUNTRY"], axis=1, inplace=True)

# %%
# replacing missing values with NaN (according to documentation)

df = df.replace(9999.9, np.nan)
df = df.replace(999.9, np.nan)
df = df.replace(99.9, np.nan)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768591 entries, 0 to 768590
# Data columns (total 22 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   STATION    768591 non-null  int64
#  1   DATE       768591 non-null  object
#  2   LATITUDE   768591 non-null  float64
#  3   LONGITUDE  768591 non-null  float64
#  4   ELEVATION  768591 non-null  float64
#  5   NAME       768591 non-null  object
#  6   TEMP       768591 non-null  float64
#  7   DEWP       765706 non-null  float64
#  8   SLP        454849 non-null  float64
#  9   STP        673907 non-null  float64
#  10  VISIB      755162 non-null  float64
#  11  WDSP       763591 non-null  float64
#  12  MXSPD      761834 non-null  float64
#  13  GUST       501242 non-null  float64
#  14  MAX        767672 non-null  float64
#  15  MIN        768214 non-null  float64
#  16  PRCP       768591 non-null  float64
#  17  SNDP       7856 non-null    float64
#  18  FRSHTT     768591 non-null  int64
#  19  COUNTRY    768591 non-null  object
#  20  LAT_NUM    768591 non-null  float64
#  21  LON_NUM    768591 non-null  float64
# dtypes: float64(17), int64(2), object(3)
# memory usage: 129.0+ MB

# %%
# creating weather type columns

df["FRSHTT"] = df["FRSHTT"].astype(str).str.zfill(6)

df[["Fog", "Rain", "Snow", "Hail", "Thunder", "Tornado"]] = (
    df["FRSHTT"]
    .apply(list)          
    .apply(pd.Series) 
    .astype(int)
)

# %%
df
# Out:
#             STATION        DATE  LATITUDE  LONGITUDE  ELEVATION  \
# 0       69015093121  2024-01-01  34.29400 -116.14722      610.5
# 1       69015093121  2024-01-02  34.29400 -116.14722      610.5
# 2       69015093121  2024-01-03  34.29400 -116.14722      610.5
# 3       69015093121  2024-01-04  34.29400 -116.14722      610.5
# 4       69015093121  2024-01-05  34.29400 -116.14722      610.5
# ...             ...         ...       ...        ...        ...
# 768586  78551011624  2024-12-27  17.69965  -64.81249       14.0
# 768587  78551011624  2024-12-28  17.69965  -64.81249       14.0
# 768588  78551011624  2024-12-29  17.69965  -64.81249       14.0
# 768589  78551011624  2024-12-30  17.69965  -64.81249       14.0
# 768590  78551011624  2024-12-31  17.69965  -64.81249       14.0
#
#                                    NAME  TEMP  DEWP     SLP    STP  ...  SNDP  \
# 0            TWENTYNINE PALMS MC, CA US  46.5  36.3  1020.4  940.5  ...   NaN
# 1            TWENTYNINE PALMS MC, CA US  49.3  33.7  1022.6  942.5  ...   NaN
# 2            TWENTYNINE PALMS MC, CA US  47.2  35.1  1018.5  938.8  ...   NaN
# 3            TWENTYNINE PALMS MC, CA US  48.8  30.1  1018.0  938.2  ...   NaN
# 4            TWENTYNINE PALMS MC, CA US  47.7  28.6  1021.6  941.6  ...   NaN
# ...                                 ...   ...   ...     ...    ...  ...   ...
# 768586  HENRY E. ROHLSEN AIRPORT, VI US  79.3  73.4  1014.2   12.3  ...   NaN
# 768587  HENRY E. ROHLSEN AIRPORT, VI US  77.3  72.2  1014.8   13.1  ...   NaN
# 768588  HENRY E. ROHLSEN AIRPORT, VI US  77.1  65.6  1014.9   13.1  ...   NaN
# 768589  HENRY E. ROHLSEN AIRPORT, VI US  76.3  65.2  1014.1   12.3  ...   NaN
# 768590  HENRY E. ROHLSEN AIRPORT, VI US  75.8  66.8  1014.1   12.5  ...   NaN
#
#         FRSHTT   LAT_NUM    LON_NUM  Fog  Rain  Snow  Hail Thunder  Tornado
# 0       000000  34.29400 -116.14722    0     0     0     0       0        0
# 1       000000  34.29400 -116.14722    0     0     0     0       0        0
# 2       010000  34.29400 -116.14722    0     1     0     0       0        0
# 3       000000  34.29400 -116.14722    0     0     0     0       0        0
# 4       000000  34.29400 -116.14722    0     0     0     0       0        0
# ...        ...       ...        ...  ...   ...   ...   ...     ...      ...
# 768586  010000  17.69965  -64.81249    0     1     0     0       0        0
# 768587  010000  17.69965  -64.81249    0     1     0     0       0        0
# 768588  000000  17.69965  -64.81249    0     0     0     0       0        0
# 768589  010000  17.69965  -64.81249    0     1     0     0       0        0
# 768590  010000  17.69965  -64.81249    0     1     0     0       0        0
#
# [768591 rows x 27 columns]

# %% [markdown]
# # Combine with Cities Dataset

# %%
# locations of cities by latitude and longitude

# https://simplemaps.com/data/us-cities

cities = pd.read_csv('uscities.csv')

cols = ["city", "state_id", "state_name", "lat", "lng"]
cities = cities[cols]
cities
# Out:
#               city state_id    state_name      lat       lng
# 0         New York       NY      New York  40.6943  -73.9249
# 1      Los Angeles       CA    California  34.1141 -118.4068
# 2          Chicago       IL      Illinois  41.8375  -87.6866
# 3            Miami       FL       Florida  25.7840  -80.2101
# 4          Houston       TX         Texas  29.7860  -95.3885
# ...            ...      ...           ...      ...       ...
# 31252   Santa Cruz       AZ       Arizona  33.2327 -112.1594
# 31253   Frankstown       PA  Pennsylvania  40.4444  -78.3558
# 31254      Ski Gap       PA  Pennsylvania  40.3160  -78.5174
# 31255      Sherman       CT   Connecticut  41.5746  -73.4957
# 31256   Twin Lakes       CA    California  38.1695 -119.3422
#
# [31257 rows x 5 columns]

# %%
import geopandas as gpd
from shapely.geometry import Point

# using geopandas to turn longitudes and latitudes into a single point

gdf_weather = gpd.GeoDataFrame(
    df, geometry=gpd.points_from_xy(df.LONGITUDE, df.LATITUDE), crs="EPSG:4326"
)

gdf_cities = gpd.GeoDataFrame(
    cities, geometry=gpd.points_from_xy(cities.lng, cities.lat), crs="EPSG:4326"
)

# %%
# using geopandas to combine cities dataset with longitudes and latitudes from df/weather dataset
# need to specify variation in longitudes and latitudes to combine
weather_geo = gdf_weather.to_crs(epsg=32631)
cities_geo = gdf_cities.to_crs(epsg=32631)

joined_weather_cities = gpd.sjoin_nearest(weather_geo, cities_geo, how="inner", max_distance=35000)
# choosing 35000m ~ 21 miles distance from point

joined_weather_cities = joined_weather_cities[joined_weather_cities["state_name"] != "Puerto Rico"]
# removing Puerto Rico to focus only on 50 states

joined_weather_cities
# Out:
#             STATION        DATE  LATITUDE  LONGITUDE  ELEVATION  \
# 0       69015093121  2024-01-01    34.294 -116.14722      610.5
# 1       69015093121  2024-01-02    34.294 -116.14722      610.5
# 2       69015093121  2024-01-03    34.294 -116.14722      610.5
# 3       69015093121  2024-01-04    34.294 -116.14722      610.5
# 4       69015093121  2024-01-05    34.294 -116.14722      610.5
# ...             ...         ...       ...        ...        ...
# 766541  74948600397  2024-12-27    39.224 -121.00300      961.0
# 766542  74948600397  2024-12-28    39.224 -121.00300      961.0
# 766543  74948600397  2024-12-29    39.224 -121.00300      961.0
# 766544  74948600397  2024-12-30    39.224 -121.00300      961.0
# 766545  74948600397  2024-12-31    39.224 -121.00300      961.0
#
#                               NAME  TEMP  DEWP     SLP    STP  ...  Hail  \
# 0       TWENTYNINE PALMS MC, CA US  46.5  36.3  1020.4  940.5  ...     0
# 1       TWENTYNINE PALMS MC, CA US  49.3  33.7  1022.6  942.5  ...     0
# 2       TWENTYNINE PALMS MC, CA US  47.2  35.1  1018.5  938.8  ...     0
# 3       TWENTYNINE PALMS MC, CA US  48.8  30.1  1018.0  938.2  ...     0
# 4       TWENTYNINE PALMS MC, CA US  47.7  28.6  1021.6  941.6  ...     0
# ...                            ...   ...   ...     ...    ...  ...   ...
# 766541   NEVADA CO AIR PARK, CA US  45.2  45.0     NaN  905.1  ...     0
# 766542   NEVADA CO AIR PARK, CA US  46.8  46.8     NaN  909.7  ...     0
# 766543   NEVADA CO AIR PARK, CA US  47.3  47.2     NaN  908.0  ...     0
# 766544   NEVADA CO AIR PARK, CA US  42.4  38.2     NaN  911.0  ...     0
# 766545   NEVADA CO AIR PARK, CA US  41.7  33.3     NaN  909.8  ...     0
#
#         Thunder  Tornado                           geometry  index_right  \
# 0             0        0  POINT (-5312673.314 13949410.334)         1683
# 1             0        0  POINT (-5312673.314 13949410.334)         1683
# 2             0        0  POINT (-5312673.314 13949410.334)         1683
# 3             0        0  POINT (-5312673.314 13949410.334)         1683
# 4             0        0  POINT (-5312673.314 13949410.334)         1683
# ...         ...      ...                                ...          ...
# 766541        0        0  POINT (-4364104.075 13829041.121)         3099
# 766542        0        0  POINT (-4364104.075 13829041.121)         3099
# 766543        0        0  POINT (-4364104.075 13829041.121)         3099
# 766544        0        0  POINT (-4364104.075 13829041.121)         3099
# 766545        0        0  POINT (-4364104.075 13829041.121)         3099
#
#                     city  state_id  state_name      lat       lng
# 0       Twentynine Palms        CA  California  34.1478 -116.0659
# 1       Twentynine Palms        CA  California  34.1478 -116.0659
# 2       Twentynine Palms        CA  California  34.1478 -116.0659
# 3       Twentynine Palms        CA  California  34.1478 -116.0659
# 4       Twentynine Palms        CA  California  34.1478 -116.0659
# ...                  ...       ...         ...      ...       ...
# 766541      Grass Valley        CA  California  39.2238 -121.0522
# 766542      Grass Valley        CA  California  39.2238 -121.0522
# 766543      Grass Valley        CA  California  39.2238 -121.0522
# 766544      Grass Valley        CA  California  39.2238 -121.0522
# 766545      Grass Valley        CA  California  39.2238 -121.0522
#
# [755327 rows x 34 columns]

# %%
joined_weather_cities = joined_weather_cities.reset_index(drop=True)
joined_weather_cities
# Out:
#             STATION        DATE  LATITUDE  LONGITUDE  ELEVATION  \
# 0       69015093121  2024-01-01    34.294 -116.14722      610.5
# 1       69015093121  2024-01-02    34.294 -116.14722      610.5
# 2       69015093121  2024-01-03    34.294 -116.14722      610.5
# 3       69015093121  2024-01-04    34.294 -116.14722      610.5
# 4       69015093121  2024-01-05    34.294 -116.14722      610.5
# ...             ...         ...       ...        ...        ...
# 755322  74948600397  2024-12-27    39.224 -121.00300      961.0
# 755323  74948600397  2024-12-28    39.224 -121.00300      961.0
# 755324  74948600397  2024-12-29    39.224 -121.00300      961.0
# 755325  74948600397  2024-12-30    39.224 -121.00300      961.0
# 755326  74948600397  2024-12-31    39.224 -121.00300      961.0
#
#                               NAME  TEMP  DEWP     SLP    STP  ...  Hail  \
# 0       TWENTYNINE PALMS MC, CA US  46.5  36.3  1020.4  940.5  ...     0
# 1       TWENTYNINE PALMS MC, CA US  49.3  33.7  1022.6  942.5  ...     0
# 2       TWENTYNINE PALMS MC, CA US  47.2  35.1  1018.5  938.8  ...     0
# 3       TWENTYNINE PALMS MC, CA US  48.8  30.1  1018.0  938.2  ...     0
# 4       TWENTYNINE PALMS MC, CA US  47.7  28.6  1021.6  941.6  ...     0
# ...                            ...   ...   ...     ...    ...  ...   ...
# 755322   NEVADA CO AIR PARK, CA US  45.2  45.0     NaN  905.1  ...     0
# 755323   NEVADA CO AIR PARK, CA US  46.8  46.8     NaN  909.7  ...     0
# 755324   NEVADA CO AIR PARK, CA US  47.3  47.2     NaN  908.0  ...     0
# 755325   NEVADA CO AIR PARK, CA US  42.4  38.2     NaN  911.0  ...     0
# 755326   NEVADA CO AIR PARK, CA US  41.7  33.3     NaN  909.8  ...     0
#
#         Thunder  Tornado                           geometry  index_right  \
# 0             0        0  POINT (-5312673.314 13949410.334)         1683
# 1             0        0  POINT (-5312673.314 13949410.334)         1683
# 2             0        0  POINT (-5312673.314 13949410.334)         1683
# 3             0        0  POINT (-5312673.314 13949410.334)         1683
# 4             0        0  POINT (-5312673.314 13949410.334)         1683
# ...         ...      ...                                ...          ...
# 755322        0        0  POINT (-4364104.075 13829041.121)         3099
# 755323        0        0  POINT (-4364104.075 13829041.121)         3099
# 755324        0        0  POINT (-4364104.075 13829041.121)         3099
# 755325        0        0  POINT (-4364104.075 13829041.121)         3099
# 755326        0        0  POINT (-4364104.075 13829041.121)         3099
#
#                     city  state_id  state_name      lat       lng
# 0       Twentynine Palms        CA  California  34.1478 -116.0659
# 1       Twentynine Palms        CA  California  34.1478 -116.0659
# 2       Twentynine Palms        CA  California  34.1478 -116.0659
# 3       Twentynine Palms        CA  California  34.1478 -116.0659
# 4       Twentynine Palms        CA  California  34.1478 -116.0659
# ...                  ...       ...         ...      ...       ...
# 755322      Grass Valley        CA  California  39.2238 -121.0522
# 755323      Grass Valley        CA  California  39.2238 -121.0522
# 755324      Grass Valley        CA  California  39.2238 -121.0522
# 755325      Grass Valley        CA  California  39.2238 -121.0522
# 755326      Grass Valley        CA  California  39.2238 -121.0522
#
# [755327 rows x 34 columns]

# %%
# creating a cleaned version of the combined weather and cities datasets

#joined_weather_cities.to_csv("weather_cities_cleaned.csv", index=False)

# %%
df2 = pd.read_csv("weather_cities_cleaned.csv")
df2
# Out:
#             STATION        DATE  LATITUDE  LONGITUDE  ELEVATION  \
# 0       69015093121  2024-01-01    34.294 -116.14722      610.5
# 1       69015093121  2024-01-02    34.294 -116.14722      610.5
# 2       69015093121  2024-01-03    34.294 -116.14722      610.5
# 3       69015093121  2024-01-04    34.294 -116.14722      610.5
# 4       69015093121  2024-01-05    34.294 -116.14722      610.5
# ...             ...         ...       ...        ...        ...
# 755322  74948600397  2024-12-27    39.224 -121.00300      961.0
# 755323  74948600397  2024-12-28    39.224 -121.00300      961.0
# 755324  74948600397  2024-12-29    39.224 -121.00300      961.0
# 755325  74948600397  2024-12-30    39.224 -121.00300      961.0
# 755326  74948600397  2024-12-31    39.224 -121.00300      961.0
#
#                               NAME  TEMP  DEWP     SLP    STP  ...  Hail  \
# 0       TWENTYNINE PALMS MC, CA US  46.5  36.3  1020.4  940.5  ...     0
# 1       TWENTYNINE PALMS MC, CA US  49.3  33.7  1022.6  942.5  ...     0
# 2       TWENTYNINE PALMS MC, CA US  47.2  35.1  1018.5  938.8  ...     0
# 3       TWENTYNINE PALMS MC, CA US  48.8  30.1  1018.0  938.2  ...     0
# 4       TWENTYNINE PALMS MC, CA US  47.7  28.6  1021.6  941.6  ...     0
# ...                            ...   ...   ...     ...    ...  ...   ...
# 755322   NEVADA CO AIR PARK, CA US  45.2  45.0     NaN  905.1  ...     0
# 755323   NEVADA CO AIR PARK, CA US  46.8  46.8     NaN  909.7  ...     0
# 755324   NEVADA CO AIR PARK, CA US  47.3  47.2     NaN  908.0  ...     0
# 755325   NEVADA CO AIR PARK, CA US  42.4  38.2     NaN  911.0  ...     0
# 755326   NEVADA CO AIR PARK, CA US  41.7  33.3     NaN  909.8  ...     0
#
#         Thunder  Tornado                                       geometry  \
# 0             0        0  POINT (-5312673.314492455 13949410.334349606)
# 1             0        0  POINT (-5312673.314492455 13949410.334349606)
# 2             0        0  POINT (-5312673.314492455 13949410.334349606)
# 3             0        0  POINT (-5312673.314492455 13949410.334349606)
# 4             0        0  POINT (-5312673.314492455 13949410.334349606)
# ...         ...      ...                                            ...
# 755322        0        0  POINT (-4364104.075319051 13829041.121093104)
# 755323        0        0  POINT (-4364104.075319051 13829041.121093104)
# 755324        0        0  POINT (-4364104.075319051 13829041.121093104)
# 755325        0        0  POINT (-4364104.075319051 13829041.121093104)
# 755326        0        0  POINT (-4364104.075319051 13829041.121093104)
#
#         index_right              city  state_id  state_name      lat       lng
# 0              1683  Twentynine Palms        CA  California  34.1478 -116.0659
# 1              1683  Twentynine Palms        CA  California  34.1478 -116.0659
# 2              1683  Twentynine Palms        CA  California  34.1478 -116.0659
# 3              1683  Twentynine Palms        CA  California  34.1478 -116.0659
# 4              1683  Twentynine Palms        CA  California  34.1478 -116.0659
# ...             ...               ...       ...         ...      ...       ...
# 755322         3099      Grass Valley        CA  California  39.2238 -121.0522
# 755323         3099      Grass Valley        CA  California  39.2238 -121.0522
# 755324         3099      Grass Valley        CA  California  39.2238 -121.0522
# 755325         3099      Grass Valley        CA  California  39.2238 -121.0522
# 755326         3099      Grass Valley        CA  California  39.2238 -121.0522
#
# [755327 rows x 34 columns]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 755327 entries, 0 to 755326
# Data columns (total 34 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   STATION      755327 non-null  int64
#  1   DATE         755327 non-null  object
#  2   LATITUDE     755327 non-null  float64
#  3   LONGITUDE    755327 non-null  float64
#  4   ELEVATION    755327 non-null  float64
#  5   NAME         755327 non-null  object
#  6   TEMP         755302 non-null  float64
#  7   DEWP         752789 non-null  float64
#  8   SLP          447235 non-null  float64
#  9   STP          662519 non-null  float64
#  10  VISIB        744484 non-null  float64
#  11  WDSP         751208 non-null  float64
#  12  MXSPD        749569 non-null  float64
#  13  GUST         492937 non-null  float64
#  14  MAX          754278 non-null  float64
#  15  MIN          754987 non-null  float64
#  16  PRCP         755327 non-null  float64
#  17  SNDP         7767 non-null    float64
#  18  FRSHTT       755327 non-null  int64
#  19  LAT_NUM      755327 non-null  float64
#  20  LON_NUM      755327 non-null  float64
#  21  Fog          755327 non-null  int64
#  22  Rain         755327 non-null  int64
#  23  Snow         755327 non-null  int64
#  24  Hail         755327 non-null  int64
#  25  Thunder      755327 non-null  int64
#  26  Tornado      755327 non-null  int64
#  27  geometry     755327 non-null  object
#  28  index_right  755327 non-null  int64
#  29  city         755327 non-null  object
#  30  state_id     755327 non-null  object
#  31  state_name   755327 non-null  object
#  32  lat          755327 non-null  float64
#  33  lng          755327 non-null  float64
# dtypes: float64(19), int64(9), object(6)
# memory usage: 195.9+ MB
